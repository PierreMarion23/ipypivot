# %%
import pandas as pd

# %%
df = pd.read_csv('pivot.tsv', sep='\t')
df.to_json('pivot.json', orient='records')
df = pd.read_json('pivot.json', orient='records')

df = df[['Key ', 'Type ', 'Default value ', 'Description']]
df
# Out:
#                   Key                  Type   \
# 0                rows      array of strings
# 1                cols      array of strings
# 2          aggregator              function
# 3      aggregatorName                string
# 4            renderer              function
# 5            rowOrder                string
# 6            colOrder                string
# 7   derivedAttributes   object of functions
# 8           dataClass              function
# 9              filter              function
# 10            sorters    object or function
# 11    rendererOptions                object
# 12      localeStrings                object
#
#                                Default value   \
# 0                                         []
# 1                                         []
# 2   $.pivotUtilities .aggregators["Count"]()
# 3                                      Count
# 4                                    table()
# 5                                 key_a_to_z
# ...

# %%
df = pd.read_csv('pivotui.tsv', sep='\t')
df.to_json('pivotui.json', orient='records')
df = pd.read_json('pivotui.json', orient='records')

df = df[['Key ', 'Type ', 'Default value ', 'Description']]
df
# Out:
#                       Key                          Type   \
# 0                    rows              array of strings
# 1                    cols              array of strings
# 2                    vals              array of strings
# 3             aggregators           object of functions
# 4          aggregatorName                        string
# 5               renderers           object of functions
# 6            rendererName                        string
# 7                rowOrder                        string
# 8                colOrder                        string
# 9       derivedAttributes           object of functions
# 10              dataClass                      function
# 11                 filter                      function
# 12             inclusions   object of arrays of strings
# 13             exclusions   object of arrays of strings
# 14       hiddenAttributes              array of strings
# 15  hiddenFromAggregators              array of strings
# ...

# %%
# df = pd.read_csv('../data/iris.csv')
# df = df.iloc[:, 1:]
# df.info()
# df.to_csv('../data/iris2.csv', index=None)
